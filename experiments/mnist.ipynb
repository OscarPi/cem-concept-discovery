# %%
import cemcd.data.mnist as mnist
import matplotlib.pyplot as plt
import pickle

# %%
with open("../results/mnist_add/run_3/state.pickle", "rb") as f:
    state = pickle.load(f)

# %%
datasets = mnist.MNISTDatasets(2, selected_digits=(0, 1, 2, 3, 4, 5, 6))

# %%
plt.hist(datasets.train_labels[:, 0][state["discovered_concept_labels"][:, 0] == 1], bins=[0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# (array([ 5., 45., 97., 90., 53., 91., 72.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(datasets.train_labels[:, 0], bins=[0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# (array([1428., 1593., 1386., 1503., 1360., 1288., 1442.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(datasets.train_labels[:, 1][state["discovered_concept_labels"][:, 0] == 1], bins=[0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# (array([  0., 398.,   7.,  48.,   0.,   0.,   0.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(datasets.train_labels[:, 1], bins=[0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# (array([1461., 1564., 1459., 1452., 1411., 1319., 1334.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)
